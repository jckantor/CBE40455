# %% [markdown]
# # Refinery Model

# %% [markdown]
# ## Getting Started

# %%
f = open('results.txt');
print(f.read())
f.close()
# Out:
# Hello, World

# %%
# %%script glpsol --out output -m /dev/stdin -o out.txt -y results.txt
#
# printf: "\nHello, World\n\n";
# end;

# %% [markdown]
# ## Simple Model

# %%
# %%script glpsol -m /dev/stdin -o /dev/stdout
#
# set PRODUCTS;
# set CRUDES;
# set INTERMEDIATES;
# set UNITS;
#
# set STREAMS := CRUDES union INTERMEDIATES union PRODUCTS;
#
# param Required{PRODUCTS} >= 0;
# param Available{CRUDES} >= 0;
# param UnitCapacity{UNITS} >= 0;
#
# var flow{STREAMS} >= 0;
# var utilization{UNITS} >= 0;
#
# # Mass Balances
#
# # Mixer/Splitter junctions
# s.t. PC01 : flow['Butane'] = flow['ButaneD'] + flow['ButaneR'] - flow['ButaneG'];
# s.t. PC02 : flow['CrackedNaphtha'] = flow['CrackedNaphthaGas'] + flow['CrackedNaphthaHO'] + flow['CrackedNaphthaDiesel'];
# s.t. PC03 : flow['CrackedGasoil'] = flow['CrackedGasoilHO'] + flow['CrackedGasoilDiesel'];
# s.t. PC04 : flow['SweetGasoil'] = flow['SweetGasoilHO'] + flow['SweetGasoilDiesel'];
#
# # Distillation Yields
# s.t. D01 : flow['ButaneD'] = 0.03*flow['1'] + 0.05*flow['2'];
# s.t. D02 : flow['Naphtha'] = 0.15*flow['1'] + 0.20*flow['2'];
# s.t. D03 : flow['Residue'] = 0.40*flow['1'] + 0.35*flow['2'];
# s.t. D04 : flow['Gasoil'] = 0.15*flow['1'] + 0.10*flow['2'];
#
# # Reformer
# s.t. R01 : flow['ButaneR'] = 0.15*flow['Naphtha'];
# s.t. R02 : flow['Reformate'] = 0.85*flow['Naphtha'];
#
# # Catalytic Cracking
# s.t. C01 : flow['CrackedNaphtha'] = 0.40*flow['Residue'];
# s.t. C02 : flow['CrackedGasoil'] = 0.35*flow['Residue'];
#
# # Desulfurization
# s.t. S01 : flow['SweetGasoil'] = flow['Gasoil'];
#
# # Blending
# s.t. GB : flow['Gasoline'] = flow['ButaneG'] + flow['Reformate'] + flow['CrackedNaphthaGas'];
# s.t. HB : flow['HeatingOil'] = flow['CrackedNaphthaHO'] + flow['CrackedGasoilHO'] + flow['SweetGasoilHO'];
# s.t. DB : flow['Diesel'] = flow['CrackedNaphthaDiesel'] + flow['CrackedGasoilDiesel'] + flow['SweetGasoilDiesel'];
#
# # Product Specifications
#
# s.t. Octane : 120*flow['ButaneG'] + 100*flow['Reformate'] + 74*flow['CrackedNaphthaGas'] >= 94*flow['Gasoline'];
# s.t. Pvap : 60*flow['ButaneG'] + 2.6*flow['Reformate'] + 4.1*flow['CrackedNaphthaGas'] <= 12.7*flow['Gasoline'];
# s.t. Vol : 105*flow['ButaneG'] + 3*flow['Reformate'] + 12*flow['CrackedNaphthaGas'] >= 17*flow['Gasoline'];
# s.t. Sulfur : 0.12*flow['CrackedNaphthaDiesel'] + 0.76*flow['CrackedGasoilDiesel'] + 0.03*flow['SweetGasoilDiesel'] <= 0.05*flow['Diesel'];
#
# # Product production constraints
# s.t. Requirement {p in PRODUCTS} : flow[p] >= Required[p];
# s.t. Availability {c in CRUDES} : flow[c] <= Available[c];
#
# s.t. Distillation : utilization['Distillation'] = sum{c in CRUDES} flow[c];
# s.t. Reforming : utilization['Reformer'] = flow['Naphtha'];
# s.t. CatCracking : utilization['CatCracker'] = flow['Residue'];
# s.t. Desulfurization : utilization['Desulfurizer'] = flow['Gasoil'];
# s.t. GasolineBlending : utilization['GasolineBlender'] = flow['Gasoline'];
# s.t. HOBlending : utilization['HOBlender'] = flow['HeatingOil'];
# s.t. DieselBlending : utilization['DieselBlender'] = flow['Diesel'];
#
# minimize cost: 2.10*utilization['Distillation'] + 4.18*utilization['Reformer'] + 2.04*utilization['Desulfurizer'] + 0.60*utilization['CatCracker'];
#
#
# data;
#
# param : CRUDES :  Available :=
#     '1'  250000
#     '2'  400000;
#
# param : PRODUCTS : Required :=
#     Butane         20000
#     Gasoline       40000
#     HeatingOil     42000
#     Diesel         30000;
#
# set INTERMEDIATES :=
#     ButaneD
#     ButaneR
#     ButaneG
#
#     Naphtha
#     Residue
#     Gasoil
#     Reformate
#
#     CrackedNaphtha
#     CrackedNaphthaGas
#     CrackedNaphthaHO
#     CrackedNaphthaDiesel
#
#     CrackedGasoil
#     CrackedGasoilHO
#     CrackedGasoilDiesel
#
#     SweetGasoil
#     SweetGasoilHO
#     SweetGasoilDiesel;
#
# param : UNITS : UnitCapacity :=
#     ADU              500000    # Atmospheric Distillation Unit
#     Distillation     500000
#     CRU               30000    # Catalytic Reformer Unit
#     Reformer          30000
#     Desulfurizer      40000
#     CCU               50000    # Catalytic Cracking Unit
#     CatCracker        50000
#     GasolineBlender  500000
#     HOBlender        500000
#     DieselBlender    500000;
#
# end;
# Out:
# GLPSOL: GLPK LP/MIP Solver, v4.52
# Parameter(s) specified in the command line:
#  -m /dev/stdin -o /dev/stdout
# Reading model section from /dev/stdin...
# Reading data section from /dev/stdin...
# /dev/stdin:113: warning: final NL missing before end of file
# 113 lines were read
# Generating PC01...
# Generating PC02...
# Generating PC03...
# Generating PC04...
# Generating D01...
# Generating D02...
# Generating D03...
# Generating D04...
# Generating R01...
# Generating R02...
# Generating C01...
# Generating C02...
# Generating S01...
# Generating GB...
# Generating HB...
# Generating DB...
# Generating Octane...
# Generating Pvap...
# Generating Vol...
# Generating Sulfur...
# Generating Requirement...
# Generating Availability...
# Generating Distillation...
# Generating Reforming...
# Generating CatCracking...
# Generating Desulfurization...
# Generating GasolineBlending...
# Generating HOBlending...
# Generating DieselBlending...
# Generating cost...
# Model has been successfully generated
# GLPK Simplex Optimizer, v4.52
# 34 rows, 30 columns, 89 non-zeros
# Preprocessing...
# 20 rows, 21 columns, 62 non-zeros
# Scaling...
#  A: min|aij| =  3.000e-02  max|aij| =  1.200e+02  ratio =  4.000e+03
# GM: min|aij| =  4.111e-01  max|aij| =  2.432e+00  ratio =  5.916e+00
# EQ: min|aij| =  1.690e-01  max|aij| =  1.000e+00  ratio =  5.916e+00
# Constructing initial basis...
# Size of triangular part is 20
#       0: obj =   0.000000000e+00  infeas =  1.179e+05 (0)
# *     8: obj =   1.265236052e+06  infeas =  0.000e+00 (0)
# OPTIMAL LP SOLUTION FOUND
# Time used:   0.0 secs
# Memory used: 0.2 Mb (175179 bytes)
# Writing basic solution to `/dev/stdout'...
# Problem:    stdin
# Rows:       34
# Columns:    30
# Non-zeros:  89
# Status:     OPTIMAL
# Objective:  cost = 1265236.052 (MINimum)
#
#    No.   Row name   St   Activity     Lower bound   Upper bound    Marginal
# ------ ------------ -- ------------- ------------- ------------- -------------
#      1 PC01         NS             0            -0             =      -63.2618
#      2 PC02         NS             0            -0             =         < eps
#      3 PC03         NS             0            -0             =         < eps
#      4 PC04         NS             0            -0             =         < eps
#      5 D01          NS             0            -0             =      -63.2618
#      6 D02          NS             0            -0             =       3.24545
#      7 D03          NS             0            -0             =           0.6
#      8 D04          NS             0            -0             =          2.04
#      9 R01          NS             0            -0             =      -63.2618
#     10 R02          NS             0            -0             =       10.0644
#     11 C01          NS             0            -0             =         < eps
#     12 C02          NS             0            -0             =         < eps
#     13 S01          NS             0            -0             =         < eps
#     14 GB           NS             0            -0             =        12.221
#     15 HB           NS             0            -0             =         < eps
#     16 DB           NS             0            -0             =         < eps
#     17 Octane       B         650815            -0
#     18 Pvap         B        -165330                          -0
#     19 Vol          NL             0            -0                    0.718884
#     20 Sulfur       NU             0                          -0         < eps
#     21 Requirement[Butane]
#                     NL         20000         20000                     63.2618
#     22 Requirement[Gasoline]
#                     B        74420.6         40000
#     23 Requirement[HeatingOil]
#                     B         106910         42000
#     24 Requirement[Diesel]
#                     NL         30000         30000                       < eps
#     25 Availability['1']
#                     B              0                      250000
#     26 Availability['2']
#                     B         377682                      400000
#     27 Distillation NS             0            -0             =           2.1
#     28 Reforming    NS             0            -0             =          4.18
#     29 CatCracking  NS             0            -0             =           0.6
#     30 Desulfurization
#                     NS             0            -0             =          2.04
#     31 GasolineBlending
#                     NS             0            -0             =         < eps
#     32 HOBlending   NS             0            -0             =         < eps
#     33 DieselBlending
#                     NS             0            -0             =         < eps
#     34 cost         B    1.26524e+06
#
#    No. Column name  St   Activity     Lower bound   Upper bound    Marginal
# ------ ------------ -- ------------- ------------- ------------- -------------
#      1 flow[Butane] B          20000             0
#      2 flow[ButaneD]
#                     B        18884.1             0
#      3 flow[ButaneR]
#                     B        11330.5             0
#      4 flow[ButaneG]
#                     B        10214.6             0
#      5 flow[CrackedNaphtha]
#                     B        52875.5             0
#      6 flow[CrackedNaphthaGas]
#                     NL             0             0                     3.59442
#      7 flow[CrackedNaphthaHO]
#                     B        46208.9             0
#      8 flow[CrackedNaphthaDiesel]
#                     B        6666.67             0
#      9 flow[CrackedGasoil]
#                     B        46266.1             0
#     10 flow[CrackedGasoilHO]
#                     B        46266.1             0
#     11 flow[CrackedGasoilDiesel]
#                     NL             0             0                       < eps
#     12 flow[SweetGasoil]
#                     B        37768.2             0
#     13 flow[SweetGasoilHO]
#                     B        14434.9             0
#     14 flow[SweetGasoilDiesel]
#                     B        23333.3             0
#     15 flow['1']    NL             0             0                     1.23496
#     16 flow['2']    B         377682             0
#     17 flow[Naphtha]
#                     B        75536.5             0
#     18 flow[Residue]
#                     B         132189             0
#     19 flow[Gasoil] B        37768.2             0
#     20 flow[Reformate]
#                     B          64206             0
#     21 flow[Gasoline]
#                     B        74420.6             0
#     22 flow[HeatingOil]
#                     B         106910             0
#     23 flow[Diesel] B          30000             0
#     24 utilization[Distillation]
#                     B         377682             0
#     25 utilization[Reformer]
#                     B        75536.5             0
#     26 utilization[CatCracker]
#                     B         132189             0
#     27 utilization[Desulfurizer]
#                     B        37768.2             0
#     28 utilization[GasolineBlender]
#                     B        74420.6             0
#     29 utilization[HOBlender]
#                     B         106910             0
#     30 utilization[DieselBlender]
#                     B          30000             0
#
# Karush-Kuhn-Tucker optimality conditions:
#
# KKT.PE: max.abs.err = 2.33e-10 on row 19
#         max.rel.err = 1.93e-16 on row 13
#         High quality
#
# KKT.PB: max.abs.err = 0.00e+00 on row 0
#         max.rel.err = 0.00e+00 on row 0
#         High quality
#
# KKT.DE: max.abs.err = 1.78e-15 on column 20
#         max.rel.err = 1.21e-16 on column 16
#         High quality
#
# KKT.DB: max.abs.err = 0.00e+00 on row 0
#         max.rel.err = 0.00e+00 on row 0
#         High quality
#
# End of output
